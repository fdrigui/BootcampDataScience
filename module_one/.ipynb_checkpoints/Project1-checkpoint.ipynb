# %%
# Importação das biblíotecas relevantes para o projeto
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
plt.style.use('ggplot')
pd.options.display.float_format = "{:,.2f}".format

# %%
# URL do arquivo CSV
filePath = 'https://raw.githubusercontent.com/fdrigui/BootcampDataScience/main/module_one/dados/A225356189_28_143_208(atend).csv'

# Abre arquivo
df_atend = pd.read_csv(filePath, sep=';', decimal=',', thousands='.', engine='python', encoding='ISO-8859-1', skiprows=3, skipfooter=12, na_values='-')
df_atend.columns = df_atend.columns.str.replace('/', '-')
df_atend = df_atend.rename(columns={'Unidade da Federação':'uf_code_and_name'})
df_atend[['uf_code', 'uf_name']] = df_atend['uf_code_and_name'].str.split(' ',n=1, expand=True).rename(columns={0:'uf_code', 1:'uf_name'})
df_atend = df_atend.dropna(axis=1, how='any')
df_atend.head()
# Out:
#   uf_code_and_name   2007-Ago   2007-Set     2007-Out     2007-Nov  \
# 0      11 Rondônia   4,209.37  16,397.03   133,645.19   346,912.84
# 1          12 Acre  10,470.07  14,001.71    86,200.85   301,323.68
# 2      13 Amazonas  35,752.72  45,570.64   416,012.30 2,020,381.79
# 3       14 Roraima   4,785.91  11,858.63    43,852.67   369,328.51
# 4          15 Pará 181,159.29 433,414.74 1,893,197.50 5,105,406.44
#
#        2007-Dez      2008-Jan      2008-Fev      2008-Mar      2008-Abr  ...  \
# 0    711,758.31  1,829,559.71  1,940,792.63  1,955,721.68  2,143,353.81  ...
# 1    769,612.36  1,731,744.62  1,743,978.66  2,057,439.02  2,057,829.69  ...
# 2  5,949,408.99 11,419,210.08  7,934,652.10  8,641,517.13  8,531,576.49  ...
# 3    470,676.43    808,448.39    771,687.83    876,091.18    896,952.53  ...
# 4 13,162,823.43 21,762,104.16 20,126,081.01 22,149,375.82 23,436,682.75  ...
#
#        2020-Set      2020-Out      2020-Nov      2020-Dez      2021-Jan  \
# 0  8,876,900.39  8,167,253.19  8,759,013.71  9,003,402.23  8,414,690.60
# 1  3,470,409.45  3,267,918.69  3,393,958.27  3,711,660.71  3,005,561.16
# 2 18,628,627.49 18,728,251.20 20,451,573.77 21,546,059.48 24,439,059.57
# 3  2,978,629.22  3,313,296.78  3,527,263.23  3,125,021.90  3,209,323.68
# 4 36,965,951.76 38,406,616.21 37,043,032.10 36,914,437.92 33,887,773.65
#
#        2021-Fev      2021-Mar            Total  uf_code   uf_name
# 0  6,039,419.59  4,732,441.04   996,411,254.68       11  Rondônia
# 1  2,272,733.90  1,137,341.65   450,048,530.47       12      Acre
# 2 13,679,358.06  6,799,060.80 1,917,247,936.05       13  Amazonas
# 3  3,044,798.77  2,381,844.31   328,876,965.09       14   Roraima
# 4 23,343,222.94 13,069,564.31 4,705,309,002.29       15      Pará
#
# [5 rows x 168 columns]

# %%
# Cria lista na mão dos códigos UF e os UFs
uf_number_code = pd.DataFrame({"uf_code":["11", "12", "13", "14", "15", "16", "17", "21", "22", "23", "24", "25", "26", "27",
                                          "28", "29", "31", "32", "33", "35", "41", "42", "43", "50", "51", "52", "53"],
                               "uf":["RO", "AC", "AM", "RR", "PA", "AP", "TO", "MA", "PI", "CE", "RN", "PB", "PE", "AL",
                                       "SE", "BA", "MG", "ES", "RJ", "SP", "PR", "SC", "RS", "MS", "MT", "GO", "DF"]})
df_atend['uf'] = df_atend['uf_code'].replace(uf_number_code['uf_code'].array,uf_number_code['uf'].array)
df_atend['uf_i'] = df_atend['uf']
df_atend = df_atend.set_index('uf_i')
df_atend['2008-Jan'] = df_atend['2008-Fev']
df_atend.head()
# Out:
#      uf_code_and_name   2007-Ago   2007-Set     2007-Out     2007-Nov  \
# uf_i
# RO        11 Rondônia   4,209.37  16,397.03   133,645.19   346,912.84
# AC            12 Acre  10,470.07  14,001.71    86,200.85   301,323.68
# AM        13 Amazonas  35,752.72  45,570.64   416,012.30 2,020,381.79
# RR         14 Roraima   4,785.91  11,858.63    43,852.67   369,328.51
# PA            15 Pará 181,159.29 433,414.74 1,893,197.50 5,105,406.44
#
#           2007-Dez      2008-Jan      2008-Fev      2008-Mar      2008-Abr  \
# uf_i
# RO      711,758.31  1,940,792.63  1,940,792.63  1,955,721.68  2,143,353.81
# AC      769,612.36  1,743,978.66  1,743,978.66  2,057,439.02  2,057,829.69
# AM    5,949,408.99  7,934,652.10  7,934,652.10  8,641,517.13  8,531,576.49
# RR      470,676.43    771,687.83    771,687.83    876,091.18    896,952.53
# PA   13,162,823.43 20,126,081.01 20,126,081.01 22,149,375.82 23,436,682.75
#
#       ...      2020-Out      2020-Nov      2020-Dez      2021-Jan  \
# uf_i  ...
# RO    ...  8,167,253.19  8,759,013.71  9,003,402.23  8,414,690.60
# AC    ...  3,267,918.69  3,393,958.27  3,711,660.71  3,005,561.16
# AM    ... 18,728,251.20 20,451,573.77 21,546,059.48 24,439,059.57
# RR    ...  3,313,296.78  3,527,263.23  3,125,021.90  3,209,323.68
# PA    ... 38,406,616.21 37,043,032.10 36,914,437.92 33,887,773.65
#
#           2021-Fev      2021-Mar            Total  uf_code   uf_name  uf
# uf_i
# RO    6,039,419.59  4,732,441.04   996,411,254.68       11  Rondônia  RO
# AC    2,272,733.90  1,137,341.65   450,048,530.47       12      Acre  AC
# AM   13,679,358.06  6,799,060.80 1,917,247,936.05       13  Amazonas  AM
# RR    3,044,798.77  2,381,844.31   328,876,965.09       14   Roraima  RR
# PA   23,343,222.94 13,069,564.31 4,705,309,002.29       15      Pará  PA
#
# [5 rows x 169 columns]

# %%
df_atend_1 = df_atend.drop(['uf_code_and_name', 'Total', 'uf_code', 'uf', 'uf_name'], axis=1)

# %%
usaveis = df_atend_1.T.loc['2008-Jan':'2019-Dez', :].copy()
usaveis.head()
# Out:
# uf_i               RO           AC           AM           RR            PA  \
# 2008-Jan 1,940,792.63 1,743,978.66 7,934,652.10   771,687.83 20,126,081.01
# 2008-Fev 1,940,792.63 1,743,978.66 7,934,652.10   771,687.83 20,126,081.01
# 2008-Mar 1,955,721.68 2,057,439.02 8,641,517.13   876,091.18 22,149,375.82
# 2008-Abr 2,143,353.81 2,057,829.69 8,531,576.49   896,952.53 23,436,682.75
# 2008-Mai 2,280,382.58 2,226,577.93 9,079,902.15 1,027,288.73 23,861,080.80
#
# uf_i               AP           TO            MA            PI            CE  \
# 2008-Jan 1,275,063.72 5,051,932.07 13,452,263.93  9,711,680.20 27,643,304.86
# 2008-Fev 1,275,063.72 5,051,932.07 13,452,263.93  9,711,680.20 27,643,304.86
# 2008-Mar 1,177,745.93 5,200,151.87 14,750,895.33 10,428,191.09 30,085,370.22
# 2008-Abr 1,396,371.51 5,343,714.73 15,148,647.11 10,227,943.00 31,376,221.00
# 2008-Mai 1,411,520.77 5,344,487.99 14,543,679.92 10,562,148.66 31,189,904.62
#
# uf_i      ...            ES            RJ             SP            PR  \
# 2008-Jan  ... 10,032,886.43 44,128,159.73 172,961,999.58 48,855,046.46
# 2008-Fev  ... 10,032,886.43 44,128,159.73 172,961,999.58 48,855,046.46
# 2008-Mar  ... 12,262,049.08 42,900,847.02 170,556,696.16 55,611,791.07
# 2008-Abr  ... 12,453,466.98 45,306,499.53 170,338,163.23 56,115,135.82
# 2008-Mai  ... 11,789,786.09 43,951,349.46 172,462,057.87 55,574,831.93
#
# uf_i                SC            RS           MS           MT            GO  \
# 2008-Jan 24,409,572.92 45,897,704.82 8,279,288.79 7,929,894.93 18,149,374.27
# 2008-Fev 24,409,572.92 45,897,704.82 8,279,288.79 7,929,894.93 18,149,374.27
# 2008-Mar 27,483,480.50 52,928,695.92 9,793,888.78 9,416,367.68 20,992,213.03
# 2008-Abr 27,806,641.44 51,972,416.77 8,997,542.75 9,390,588.03 21,049,477.30
# 2008-Mai 28,354,279.52 51,679,350.79 9,842,108.59 9,378,197.25 19,162,546.79
#
# uf_i                DF
# 2008-Jan 10,215,956.80
# 2008-Fev 10,215,956.80
# 2008-Mar 11,627,918.26
# 2008-Abr 11,922,015.36
# 2008-Mai 11,900,817.00
#
# [5 rows x 27 columns]

# %%
usaveis['SP'].plot()
# Out:
# <AxesSubplot:>

# %%
pop = pd.read_csv('dados/pop.csv', sep=';', decimal=',', thousands='.', engine='python', encoding='ISO-8859-1', skiprows=3, skipfooter=12, na_values='-')
pop = pop.set_index('Ano')
pop = pop.drop('Total', axis=1)
pop.head()
# Out:
#            RO      AC       AM      RR       PA      AP       TO       MA  \
# Ano
# 2008  1493566  680073  3341096  412783  7321493  613164  1280509  6305539
# 2009  1503928  691132  3393369  421499  7457119  626609  1292051  6367138
# 2010  1560501  732793  3480937  451227  7588078  668689  1383453  6569683
# 2011  1576455  746386  3538387  460165  7688593  684309  1400892  6645761
# 2012  1590011  758786  3590985  469524  7822205  698602  1417694  6714314
#
#            PI       CE  ...       ES        RJ        SP        PR       SC  \
# Ano                     ...
# 2008  3119697  8450527  ...  3453648  15872362  41011635  10590169  6052587
# 2009  3145325  8547809  ...  3487199  16010429  41384039  10686247  6118743
# 2010  3119015  8448055  ...  3512672  15993583  41252160  10439601  6249682
# 2011  3140328  8530155  ...  3547055  16112678  41587182  10512349  6317054
# 2012  3160748  8606005  ...  3578067  16231365  41901219  10577755  6383286
#
#             RS       MS       MT       GO       DF
# Ano
# 2008  10855214  2336058  2957732  5844996  2557158
# 2009  10914128  2360498  3001692  5926300  2606885
# 2010  10695532  2449341  3033991  6004045  2562963
# 2011  10733030  2477542  3075936  6080716  2609998
# 2012  10770603  2505088  3115336  6154996  2648532
#
# [5 rows x 27 columns]

# %%
usaveis[['ano', 'mes']] = usaveis.index.to_series().str.split('-',n=1, expand=True).rename(columns={0:'ano', 1:'mes'})

# %%
usaveis[usaveis['ano']=='2008'].loc[:,'RO':'DF'].div(pop.loc[2008], axis=1)
# Out:
# uf_i       RO   AC   AM   RR   PA   AP   TO   MA   PI   CE  ...   ES   RJ  \
# 2008-Jan 1.30 2.56 2.37 1.87 2.75 2.08 3.95 2.13 3.11 3.27  ... 2.91 2.78
# 2008-Fev 1.30 2.56 2.37 1.87 2.75 2.08 3.95 2.13 3.11 3.27  ... 2.91 2.78
# 2008-Mar 1.31 3.03 2.59 2.12 3.03 1.92 4.06 2.34 3.34 3.56  ... 3.55 2.70
# 2008-Abr 1.44 3.03 2.55 2.17 3.20 2.28 4.17 2.40 3.28 3.71  ... 3.61 2.85
# 2008-Mai 1.53 3.27 2.72 2.49 3.26 2.30 4.17 2.31 3.39 3.69  ... 3.41 2.77
# 2008-Jun 1.76 3.11 2.59 2.27 3.21 2.32 4.22 2.31 3.35 3.49  ... 3.44 2.78
# 2008-Jul 1.99 2.98 2.62 2.43 3.08 2.23 3.95 2.31 3.40 3.59  ... 3.53 2.79
# 2008-Ago 1.97 2.77 2.49 2.53 3.18 2.53 4.07 2.32 3.41 3.47  ... 3.59 2.68
# 2008-Set 1.90 3.07 2.44 2.43 3.23 2.53 4.06 2.43 3.54 3.60  ... 3.62 2.71
# 2008-Out 1.93 3.28 2.30 2.56 3.19 2.67 4.70 2.48 3.57 3.76  ... 3.72 2.81
# 2008-Nov 1.86 3.12 2.32 2.96 3.21 2.69 4.06 2.48 3.39 3.60  ... 3.73 2.61
# 2008-Dez 1.78 3.23 2.32 3.00 3.26 2.69 4.38 2.32 3.25 3.58  ... 3.63 2.71
#
# uf_i       SP   PR   SC   RS   MS   MT   GO   DF
# 2008-Jan 4.22 4.61 4.03 4.23 3.54 2.68 3.11 4.00
# 2008-Fev 4.22 4.61 4.03 4.23 3.54 2.68 3.11 4.00
# 2008-Mar 4.16 5.25 4.54 4.88 4.19 3.18 3.59 4.55
# 2008-Abr 4.15 5.30 4.59 4.79 3.85 3.17 3.60 4.66
# 2008-Mai 4.21 5.25 4.68 4.76 4.21 3.17 3.28 4.65
# 2008-Jun 4.28 5.30 4.79 4.95 4.39 3.20 3.48 4.68
# 2008-Jul 4.38 5.65 4.96 5.19 4.35 3.31 3.43 4.42
# 2008-Ago 4.39 5.35 4.77 5.18 4.11 3.04 3.60 4.52
# 2008-Set 4.39 5.49 5.08 5.33 4.40 2.99 3.66 4.86
# 2008-Out 4.68 5.79 5.17 5.49 4.63 3.12 3.53 4.86
# 2008-Nov 4.66 5.63 4.96 5.30 4.44 3.20 3.41 4.81
# 2008-Dez 4.32 5.46 5.03 5.13 3.91 3.11 3.31 4.69
#
# [12 rows x 27 columns]
